# %%
'''Create Python variables to store the following details

Your name
Age
City
College/company name
Current learning topic
Years of experience or study

Whether you like Python (True/False)

Your expected salary after learning Python

Print every value.

Then print the data type of every variable using type().

Concepts

Variables, string, integer, float, boolean, print(), type().'''

name = 'Alice'
age = 25
city = 'Hydrabad'
college_name = 'XYZ University'
Current_Learning_topic = 'Python Programming'
years_of_experience = 3
Like_Python = True
expected_salary = 70000.00

print(f'Name: {name}')
print(f'Age: {age}')
print(f'city: {city}')
print(f'College_Name: {college_name}')
print(f'Current_Learning_topic: {Current_Learning_topic}')
print(f'Years_of_experience: {years_of_experience}')
print(f'Like_Python: {Like_Python}')
print(f'Expected_Salary: {expected_salary}')
print(f'Expected_Salary: {expected_salary:.2f}')

print('Type of name:',type(name))
print('Type of age:',type(age))
print('Type of city:',type(city))
print('Type of college_name:',type(college_name))
print('Type of Current_learing_topic:',type(Current_Learning_topic))
print('Type of years_of_experience:',type(years_of_experience))
print('Type of Like_Python:',type(Like_Python))
print('Type of expected_salary:',type(expected_salary))
# Out:
# Name: Alice
# Age: 25
# city: Hydrabad
# College_Name: XYZ University
# Current_Learning_topic: Python Programming
# Years_of_experience: 3
# Like_Python: True
# Expected_Salary: 70000.0
# Expected_Salary: 70000.00
# Type of name: <class 'str'>
# Type of age: <class 'int'>
# Type of city: <class 'str'>
# Type of college_name: <class 'str'>
# Type of Current_learing_topic: <class 'str'>
# Type of years_of_experience: <class 'int'>
# Type of Like_Python: <class 'bool'>
# Type of expected_salary: <class 'float'>
